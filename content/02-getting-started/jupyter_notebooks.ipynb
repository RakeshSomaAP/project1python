# %%
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1559/244804411.py in <cell line: 0>()
# ----> 1 Print("Hello")
#
# NameError: name 'Print' is not defined
